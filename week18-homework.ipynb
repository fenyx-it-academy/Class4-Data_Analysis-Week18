# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/weather-dataset-rattle-package/weatherAUS.csv

# %% [markdown]
# Read the dataset as a dataframe. Create a copy of your dataframe. Solve the rest of the questions using this dataframe copy.

# %%
d18 = pd.read_csv('../input/weather-dataset-rattle-package/weatherAUS.csv')
d18
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# Find out the describe and info attributes of the dataframe. Analyze these information and create a short write-up according to your findings.

# %%
print(d18.info())
d18.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# Find out the shape and size info of the dataset.

# %%
print('The shape: ',d18.shape)
print('The size: ', d18.size)
# Out:
# The shape:  (145460, 23)
# The size:  3345580

# %% [markdown]
# Find out the types values of the columns and save the result as a dataframe.

# %%
dtypes_d18 = pd.DataFrame(d18.dtypes,columns=['dtypes'])
dtypes_d18
# Out:
#                 dtypes
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %% [markdown]
# Find out the non-null counts of the columns and save the result as a dataframe.

# %%
nonnull_d18 = pd.DataFrame(d18.notnull().sum())

nonnull_d18
# Out:
#                     0
# Date           145460
# Location       145460
# MinTemp        143975
# MaxTemp        144199
# Rainfall       142199
# Evaporation     82670
# Sunshine        75625
# WindGustDir    135134
# WindGustSpeed  135197
# WindDir9am     134894
# WindDir3pm     141232
# WindSpeed9am   143693
# WindSpeed3pm   142398
# Humidity9am    142806
# Humidity3pm    140953
# Pressure9am    130395
# Pressure3pm    130432
# Cloud9am        89572
# Cloud3pm        86102
# Temp9am        143693
# Temp3pm        141851
# RainToday      142199
# RainTomorrow   142193

# %% [markdown]
# Find out the null counts of the columns and save the result as a dataframe.

# %%
null_d18 = pd.DataFrame(d18.isnull().sum())
null_d18
# Out:
#                    0
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# Evaporation    62790
# Sunshine       69835
# WindGustDir    10326
# WindGustSpeed  10263
# WindDir9am     10566
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Pressure9am    15065
# Pressure3pm    15028
# Cloud9am       55888
# Cloud3pm       59358
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267

# %% [markdown]
# Find out the unique counts of the columns and save the result as a dataframe.

# %%
nunique_d18 = pd.DataFrame(d18.nunique())
nunique_d18
# Out:
#                   0
# Date           3436
# Location         49
# MinTemp         389
# MaxTemp         505
# Rainfall        681
# Evaporation     358
# Sunshine        145
# WindGustDir      16
# WindGustSpeed    67
# WindDir9am       16
# WindDir3pm       16
# WindSpeed9am     43
# WindSpeed3pm     44
# Humidity9am     101
# Humidity3pm     101
# Pressure9am     546
# Pressure3pm     549
# Cloud9am         10
# Cloud3pm         10
# Temp9am         441
# Temp3pm         502
# RainToday         2
# RainTomorrow      2

# %% [markdown]
# Merge the dataframes you created in questions 4-5-6-7. Expected output:

# %%
merge18 = pd.concat([dtypes_d18,null_d18,nonnull_d18, nunique_d18], axis=1)
merge18
# Out:
#                 dtypes      0       0     0
# Date            object      0  145460  3436
# Location        object      0  145460    49
# MinTemp        float64   1485  143975   389
# MaxTemp        float64   1261  144199   505
# Rainfall       float64   3261  142199   681
# Evaporation    float64  62790   82670   358
# Sunshine       float64  69835   75625   145
# WindGustDir     object  10326  135134    16
# WindGustSpeed  float64  10263  135197    67
# WindDir9am      object  10566  134894    16
# WindDir3pm      object   4228  141232    16
# WindSpeed9am   float64   1767  143693    43
# WindSpeed3pm   float64   3062  142398    44
# Humidity9am    float64   2654  142806   101
# Humidity3pm    float64   4507  140953   101
# Pressure9am    float64  15065  130395   546
# Pressure3pm    float64  15028  130432   549
# Cloud9am       float64  55888   89572    10
# Cloud3pm       float64  59358   86102    10
# Temp9am        float64   1767  143693   441
# ...

# %% [markdown]
# Lowercase all column names.

# %%
d18.columns = list(map(lambda x: x.lower(), d18.columns))
d18.sample()
# Out:
#               date      location  mintemp  maxtemp  rainfall  evaporation  \
# 102427  2017-02-20  MountGambier      7.2     20.0       2.4          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# 102427       NaN          SW           41.0         SW  ...        69.0
#
#         humidity3pm  pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  \
# 102427         50.0       1017.0       1017.0       7.0       8.0     14.2
#
#         temp3pm  raintoday  raintomorrow
# 102427     17.6        Yes            No
#
# [1 rows x 23 columns]

# %% [markdown]
# Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

# %%
d18.raintoday.replace('no', 'noRain', inplace=True)
d18.raintomorrow.replace('no', 'noRain', inplace=True)

d18
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %% [markdown]
# Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.

# %%
d18.date = pd.to_datetime(d18.date)
d18.date = d18.date.dt.strftime('%d/%m/%Y')
d18.head()
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04/12/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05/12/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity9am  humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# ...

# %% [markdown]
# Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
d18['difference'] = d18['maxtemp'] - d18['mintemp']
d18['difference']
# Out:
# 0          9.5
# 1         17.7
# 2         12.8
# 3         18.8
# 4         14.8
#           ...
# 145455    20.6
# 145456    21.7
# 145457    21.5
# 145458    19.2
# 145459     NaN
# Name: difference, Length: 145460, dtype: float64

# %% [markdown]
# Remove the evaporation and sunshine columns from the dataset permanently.

# %%
#d18.drop(['evaporation','sunshine'], axis=1 ,inplace=True )
d18.head()
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04/12/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05/12/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity3pm  pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  raintomorrow  \
# ...

# %% [markdown]
# Find out the most rainy day for each city.

# %%
d18.groupby('location')['rainfall','date'].max()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                   rainfall        date
# location
# Adelaide              75.2  31/12/2016
# Albany                49.4  31/12/2016
# Albury               104.2  31/12/2016
# AliceSprings          62.0  31/12/2016
# BadgerysCreek        116.0  31/12/2016
# Ballarat              95.0  31/12/2016
# Bendigo               66.4  31/12/2016
# Brisbane             182.6  31/12/2016
# Cairns               278.4  31/12/2016
# Canberra              87.0  31/12/2016
# Cobar                 68.0  31/12/2016
# CoffsHarbour         371.0  31/12/2016
# Dartmoor              73.6  31/12/2016
# Darwin               367.6  31/12/2016
# GoldCoast            183.4  31/12/2016
# Hobart                71.6  31/12/2016
# Katherine            167.0  31/12/2016
# ...

# %% [markdown]
# Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
filter_d18 = d18[d18['location']=='Albury']
filter_d18.sort_values(by=['maxtemp'])
# Out:
#             date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 2328  15/07/2015   Albury      4.4      6.8      10.0          NaN       NaN
# 2675  26/06/2016   Albury     -1.3      7.5       0.0          NaN       NaN
# 193   12/06/2009   Albury     -1.3      8.2       0.0          NaN       NaN
# 2673  24/06/2016   Albury      6.6      8.2       4.0          NaN       NaN
# 919   08/07/2011   Albury     -0.5      8.3       0.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 984   11/09/2011   Albury      NaN      NaN       NaN          NaN       NaN
# 985   12/09/2011   Albury      NaN      NaN       NaN          NaN       NaN
# 1529  07/05/2013   Albury      3.9      NaN       0.0          NaN       NaN
# 2031  21/09/2014   Albury      3.4      NaN       0.0          NaN       NaN
# 2032  22/09/2014   Albury      NaN      NaN       NaN          NaN       NaN
#
# ...

# %% [markdown]
# Find out the NaN counts for each column.

# %%
NaN_d18 = d18.isnull().sum()
NaN_d18
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# evaporation      62790
# sunshine         69835
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %% [markdown]
# Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
d18.dropna(subset=['windgustdir'], axis=0, inplace=True)
d18
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       01/12/2008   Albury     13.4     22.9       0.6          NaN
# 1       02/12/2008   Albury      7.4     25.1       0.0          NaN
# 2       03/12/2008   Albury     12.9     25.7       0.0          NaN
# 3       04/12/2008   Albury      9.2     28.0       0.0          NaN
# 4       05/12/2008   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  20/06/2017    Uluru      3.5     21.8       0.0          NaN
# 145455  21/06/2017    Uluru      2.8     23.4       0.0          NaN
# 145456  22/06/2017    Uluru      3.6     25.3       0.0          NaN
# 145457  23/06/2017    Uluru      5.4     26.9       0.0          NaN
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity3pm  \
# ...

# %% [markdown]
# Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
d18a = d18.copy()
d18_min = d18a.groupby('location')[['evaporation', 'sunshine']].min()
d18_min
# Out:
#                   evaporation  sunshine
# location
# Adelaide                  0.0       0.0
# Albury                    NaN       NaN
# AliceSprings              0.0       0.0
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   0.0       NaN
# Brisbane                  0.0       0.0
# Cairns                    0.2       0.0
# Canberra                  0.0       0.0
# Cobar                     0.0       0.0
# CoffsHarbour              0.0       0.0
# Dartmoor                  0.0       0.0
# Darwin                    0.2       0.0
# GoldCoast                 NaN       NaN
# Hobart                    0.0       0.0
# Katherine                 0.0       NaN
# Launceston                0.0       NaN
# Melbourne                 0.0       0.0
# MelbourneAirport          0.0       0.0
# Mildura                   0.0       0.0
# Moree                     0.2       0.0
# MountGambier              0.0       0.0
# ...

# %%
d18_max = d18a.groupby('location')[['evaporation', 'sunshine']].max()
d18_max
# Out:
#                   evaporation  sunshine
# location
# Adelaide                 43.4      13.9
# Albury                    NaN       NaN
# AliceSprings             50.2      13.4
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                  15.4       NaN
# Brisbane                 44.0      13.5
# Cairns                   44.4      12.8
# Canberra                 17.2      13.6
# Cobar                    86.2      13.7
# CoffsHarbour             19.8      13.8
# Dartmoor                 16.4      14.3
# Darwin                   19.2      12.3
# GoldCoast                 NaN       NaN
# Hobart                   20.2      14.2
# Katherine                31.0       NaN
# Launceston               30.4       NaN
# Melbourne                23.8      13.9
# MelbourneAirport         23.8      13.9
# Mildura                  23.2      14.5
# Moree                    65.4      14.0
# MountGambier             16.4      14.3
# ...

# %%
d18_median = d18a.groupby('location')[['evaporation', 'sunshine']].median()
d18_median
# Out:
#                   evaporation  sunshine
# location
# Adelaide                  4.2       8.4
# Albury                    NaN       NaN
# AliceSprings              8.2      10.6
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   3.1       NaN
# Brisbane                  5.2       9.4
# Cairns                    6.0       8.6
# Canberra                  3.4       8.1
# Cobar                     5.6       9.9
# CoffsHarbour              3.6       8.5
# Dartmoor                  2.6       6.4
# Darwin                    6.4      10.0
# GoldCoast                 NaN       NaN
# Hobart                    3.2       6.9
# Katherine                 7.2       NaN
# Launceston                5.2       NaN
# Melbourne                 4.0       6.5
# MelbourneAirport          4.0       6.5
# Mildura                   5.2       9.1
# Moree                     6.4      10.1
# MountGambier              2.8       6.5
# ...

# %% [markdown]
# Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
result=d18[d18.location=='Perth'][['location','date','maxtemp']].sort_values(by=['maxtemp'], ascending=False)
result.iloc[0]
# Out:
# location         Perth
# date        05/01/2015
# maxtemp           44.4
# Name: 122928, dtype: object

# %% [markdown]
# Group your dataframe by location and find out the averages of all numeric values.

# %%
result1 = d18.groupby('location').mean()
result1
# Out:
#                     mintemp    maxtemp  rainfall  evaporation  sunshine  \
# location
# Adelaide          12.571487  22.891254  1.576076     5.757117  7.742417
# Albury             9.518588  22.629555  1.904552          NaN       NaN
# AliceSprings      13.155254  29.281325  0.869484     9.042405  9.592820
# BadgerysCreek     11.135741  24.014949  2.215406          NaN       NaN
# Ballarat           7.348670  18.267930  1.706369          NaN       NaN
# Bendigo            8.611841  21.625609  1.631586     3.835616       NaN
# Brisbane          16.414204  26.436043  3.119424     5.406064  8.069265
# Cairns            21.225099  29.559550  5.701852     6.244197  7.577948
# Canberra           6.670100  20.731579  1.745920     4.134289  7.419064
# Cobar             13.131412  25.853488  1.132655     6.751995  8.693236
# CoffsHarbour      14.522998  23.971493  4.990985     3.912857  7.353320
# Dartmoor           8.620518  19.696769  2.150272     3.354226  6.419215
# ...
