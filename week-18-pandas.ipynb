# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/weather-dataset-rattle-package/weatherAUS.csv

# %%
df = pd.read_csv('/kaggle/input/weather-dataset-rattle-package/weatherAUS.csv')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# 1. Read the dataset as a dataframe. Create a copy of your dataframe. Solve the rest of the questions using this dataframe copy.

# %%
tdf = df.copy()
tdf
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
print(type(tdf))
print("********************")
print(tdf.shape)  #satir ve sutun sayilari hakkinda bilgi verir
print("********************")
print(tdf.size) # icinde kac eleman oldugunu soyler
print("********************")
print(tdf.dtypes)
print("********************")
print(tdf.index)  # index hakkinda bize bilgiler verir
print("********************")
print(tdf.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ********************
# (145460, 23)
# ********************
# 3345580
# ********************
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object
# ********************
# RangeIndex(start=0, stop=145460, step=1)
# ********************
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
# ...

# %% [markdown]
# 2. Find out the describe and info attributes of the dataframe. Analyze these information and create a short write-up according to your findings.

# %%
tdf.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# 3. Find out the shape and size info of the dataset.

# %%
tdf.shape
# Out:
# (145460, 23)

# %%
tdf.size
# Out:
# 3345580

# %% [markdown]
# 4. Find out the types values of the columns and save the result as a dataframe.

# %%
dtypes=tdf.dtypes
dtypes = pd.DataFrame(dtypes, columns = ['dtypes'] )
dtypes
# Out:
#                 dtypes
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %% [markdown]
# 5) Find out the non-null counts of the columns and save the result as a dataframe.

# %%
nonnull = pd.DataFrame(tdf.count(), columns = ['nonnull'] )
nonnull
# Out:
#                nonnull
# Date            145460
# Location        145460
# MinTemp         143975
# MaxTemp         144199
# Rainfall        142199
# Evaporation      82670
# Sunshine         75625
# WindGustDir     135134
# WindGustSpeed   135197
# WindDir9am      134894
# WindDir3pm      141232
# WindSpeed9am    143693
# WindSpeed3pm    142398
# Humidity9am     142806
# Humidity3pm     140953
# Pressure9am     130395
# Pressure3pm     130432
# Cloud9am         89572
# Cloud3pm         86102
# Temp9am         143693
# Temp3pm         141851
# RainToday       142199
# RainTomorrow    142193

# %% [markdown]
# 6. Find out the null counts of the columns and save the result as a dataframe.

# %%
isnull = pd.DataFrame(tdf.isnull().sum(), columns = ['isnull'] )
isnull
# Out:
#                isnull
# Date                0
# Location            0
# MinTemp          1485
# MaxTemp          1261
# Rainfall         3261
# Evaporation     62790
# Sunshine        69835
# WindGustDir     10326
# WindGustSpeed   10263
# WindDir9am      10566
# WindDir3pm       4228
# WindSpeed9am     1767
# WindSpeed3pm     3062
# Humidity9am      2654
# Humidity3pm      4507
# Pressure9am     15065
# Pressure3pm     15028
# Cloud9am        55888
# Cloud3pm        59358
# Temp9am          1767
# Temp3pm          3609
# RainToday        3261
# RainTomorrow     3267

# %% [markdown]
# 7) Find out the unique counts of the columns and save the result as a dataframe.

# %%
nununique = pd.DataFrame(tdf.nunique(), columns = ['nununique'] )
nununique
# Out:
#                nununique
# Date                3436
# Location              49
# MinTemp              389
# MaxTemp              505
# Rainfall             681
# Evaporation          358
# Sunshine             145
# WindGustDir           16
# WindGustSpeed         67
# WindDir9am            16
# WindDir3pm            16
# WindSpeed9am          43
# WindSpeed3pm          44
# Humidity9am          101
# Humidity3pm          101
# Pressure9am          546
# Pressure3pm          549
# Cloud9am              10
# Cloud3pm              10
# Temp9am              441
# Temp3pm              502
# RainToday              2
# RainTomorrow           2

# %% [markdown]
# 8) Merge the dataframes you created in questions 4-5-6-7. Expected output:

# %%
frames = [ dtypes, nonnull, isnull, nununique]
frames1= pd.concat((frames), axis = 1, ignore_index = False)
frames1.reset_index(inplace=True)
frames1=frames1.rename(columns={'index':"Columns"})
frames1
# Out:
#           Columns   dtypes  nonnull  isnull  nununique
# 0            Date   object   145460       0       3436
# 1        Location   object   145460       0         49
# 2         MinTemp  float64   143975    1485        389
# 3         MaxTemp  float64   144199    1261        505
# 4        Rainfall  float64   142199    3261        681
# 5     Evaporation  float64    82670   62790        358
# 6        Sunshine  float64    75625   69835        145
# 7     WindGustDir   object   135134   10326         16
# 8   WindGustSpeed  float64   135197   10263         67
# 9      WindDir9am   object   134894   10566         16
# 10     WindDir3pm   object   141232    4228         16
# 11   WindSpeed9am  float64   143693    1767         43
# 12   WindSpeed3pm  float64   142398    3062         44
# 13    Humidity9am  float64   142806    2654        101
# 14    Humidity3pm  float64   140953    4507        101
# 15    Pressure9am  float64   130395   15065        546
# ...

# %% [markdown]
# 9) Lowercase all column names.

# %%
tdf.columns = map(str.lower, tdf.columns)
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %% [markdown]
# 10) Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

# %%
tdf.raintoday.replace('No', 'noRain', inplace=True)
tdf.raintomorrow.replace('No', 'noRain', inplace=True)
tdf.raintoday.replace('Yes', 'Rain', inplace=True)
tdf.raintomorrow.replace('Yes', 'Rain', inplace=True)
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %% [markdown]
# 11) Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.

# %%
tdf['date'] = pd.to_datetime(tdf['date'], format='%Y-%m-%d').dt.strftime('%d/%m/%Y')
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       01/12/2008   Albury     13.4     22.9       0.6          NaN
# 1       02/12/2008   Albury      7.4     25.1       0.0          NaN
# 2       03/12/2008   Albury     12.9     25.7       0.0          NaN
# 3       04/12/2008   Albury      9.2     28.0       0.0          NaN
# 4       05/12/2008   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  21/06/2017    Uluru      2.8     23.4       0.0          NaN
# 145456  22/06/2017    Uluru      3.6     25.3       0.0          NaN
# 145457  23/06/2017    Uluru      5.4     26.9       0.0          NaN
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          NaN
# 145459  25/06/2017    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %% [markdown]
# 13) Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
tdf['difference'] = tdf['maxtemp'] - tdf['mintemp']
tdf.difference
# Out:
# 0          9.5
# 1         17.7
# 2         12.8
# 3         18.8
# 4         14.8
#           ...
# 145455    20.6
# 145456    21.7
# 145457    21.5
# 145458    19.2
# 145459     NaN
# Name: difference, Length: 145460, dtype: float64

# %% [markdown]
# 14) Remove the evaporation and sunshine columns from the dataset permanently.

# %%
tdf.drop(['evaporation', 'sunshine'], axis=1, inplace=True)
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01/12/2008   Albury     13.4     22.9       0.6           W
# 1       02/12/2008   Albury      7.4     25.1       0.0         WNW
# 2       03/12/2008   Albury     12.9     25.7       0.0         WSW
# 3       04/12/2008   Albury      9.2     28.0       0.0          NE
# 4       05/12/2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455  21/06/2017    Uluru      2.8     23.4       0.0           E
# 145456  22/06/2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23/06/2017    Uluru      5.4     26.9       0.0           N
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          SE
# 145459  25/06/2017    Uluru     14.9      NaN       0.0         NaN
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %% [markdown]
# 14) Find out the most rainy day for each city.

# %%
cities = tdf.drop_duplicates(subset = ["location"])
cities.location
# Out:
# 0                   Albury
# 3040         BadgerysCreek
# 6049                 Cobar
# 9058          CoffsHarbour
# 12067                Moree
# 18115            NorahHead
# 21119        NorfolkIsland
# 24128              Penrith
# 27167             Richmond
# 31155               Sydney
# 33520        SydneyAirport
# 36529           WaggaWagga
# 39538          Williamtown
# 42549           Wollongong
# 45587             Canberra
# 49023          Tuggeranong
# 52205          MountGinini
# 55102             Ballarat
# 58142              Bendigo
# 61182                 Sale
# 64191     MelbourneAirport
# 67200            Melbourne
# 70393              Mildura
# 73402                 Nhil
# 74980             Portland
# 77989             Watsonia
# 81061             Dartmoor
# 84007             Brisbane
# 87200               Cairns
# 90240            GoldCoast
# 93280           Townsville
# 96320             Adelaide
# 99513         MountGambier
# 102553           Nuriootpa
# ...

# %%
tdf.loc[tdf.groupby('location').rainfall.idxmax()]
# Out:
#               date          location  mintemp  maxtemp  rainfall windgustdir  \
# 98285   14/02/2014          Adelaide     20.6     24.5      75.2          NE
# 1156    01/03/2012            Albury     17.1     20.9     104.2          SE
# 136525  28/02/2010      AliceSprings     18.8     19.8      62.0          SE
# 4468    29/01/2013     BadgerysCreek     18.3     28.1     116.0         WSW
# 55898   05/02/2011          Ballarat     15.3     18.1      70.4          SW
# 58938   05/02/2011           Bendigo     20.7     21.3      66.4           N
# 86414   02/05/2015          Brisbane     16.6     24.9     182.6         SSW
# 87242   12/01/2009            Cairns     22.3     27.4     278.4          NW
# 46715   03/12/2010          Canberra     13.4     22.4      87.0           W
# 7832    16/02/2014             Cobar     21.4     28.6      68.0          SW
# 11681   05/06/2016      CoffsHarbour     14.6     19.2     219.6         WSW
# ...

# %% [markdown]
# 15) Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
tdf[tdf.location == 'Albury'].sort_values(by='maxtemp', ascending=False)
# Out:
#             date location  mintemp  maxtemp  rainfall windgustdir  \
# 68    07/02/2009   Albury     22.3     44.8       0.0         NNW
# 2904  10/02/2017   Albury     23.0     43.7       0.0         WSW
# 1783  16/01/2014   Albury     23.0     43.6       0.0           N
# 1435  05/01/2013   Albury     19.8     43.4       0.0          NW
# 62    01/02/2009   Albury     28.0     43.1       0.0          SW
# ...          ...      ...      ...      ...       ...         ...
# 984   11/09/2011   Albury      NaN      NaN       NaN         NaN
# 985   12/09/2011   Albury      NaN      NaN       NaN         NaN
# 1529  07/05/2013   Albury      3.9      NaN       0.0         NaN
# 2031  21/09/2014   Albury      3.4      NaN       0.0         NaN
# 2032  22/09/2014   Albury      NaN      NaN       NaN         NaN
#
#       windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 68             59.0         SE         NW           9.0  ...         11.0
# ...

# %% [markdown]
# 16) Find out the NaN counts for each column.

# %%
 tdf.isna().sum()
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %% [markdown]
# 17) Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
tdf.dropna(subset=['windgustdir'], inplace=True)
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01/12/2008   Albury     13.4     22.9       0.6           W
# 1       02/12/2008   Albury      7.4     25.1       0.0         WNW
# 2       03/12/2008   Albury     12.9     25.7       0.0         WSW
# 3       04/12/2008   Albury      9.2     28.0       0.0          NE
# 4       05/12/2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145454  20/06/2017    Uluru      3.5     21.8       0.0           E
# 145455  21/06/2017    Uluru      2.8     23.4       0.0           E
# 145456  22/06/2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23/06/2017    Uluru      5.4     26.9       0.0           N
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          SE
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %% [markdown]
# 18) Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
tdf1 = df.copy()
tdf1=tdf1.sort_values(by='Location').groupby('Location').agg({'Evaporation': max, 'Sunshine':max})
tdf1
#sort_values(by='Location')
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                 43.4      13.9
# Albany                   33.6      13.8
# Albury                    NaN       NaN
# AliceSprings             50.2      13.5
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                  15.4       NaN
# Brisbane                 44.0      13.5
# Cairns                   44.4      12.8
# Canberra                 20.0      13.6
# Cobar                    86.2      13.7
# CoffsHarbour             19.8      13.8
# Dartmoor                 16.4      14.3
# Darwin                   19.2      12.3
# GoldCoast                 NaN       NaN
# Hobart                   20.2      14.2
# Katherine                31.0       NaN
# Launceston               30.4       NaN
# Melbourne                23.8      13.9
# MelbourneAirport         23.8      13.9
# Mildura                  23.2      14.5
# Moree                    65.4      14.0
# ...

# %%
tdf2 = df.copy()
tdf2=tdf2.sort_values(by='Location').groupby('Location').agg({'Evaporation': min, 'Sunshine':min})
tdf2
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                  0.0       0.0
# Albany                    0.0       0.0
# Albury                    NaN       NaN
# AliceSprings              0.0       0.0
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   0.0       NaN
# Brisbane                  0.0       0.0
# Cairns                    0.2       0.0
# Canberra                  0.0       0.0
# Cobar                     0.0       0.0
# CoffsHarbour              0.0       0.0
# Dartmoor                  0.0       0.0
# Darwin                    0.2       0.0
# GoldCoast                 NaN       NaN
# Hobart                    0.0       0.0
# Katherine                 0.0       NaN
# Launceston                0.0       NaN
# Melbourne                 0.0       0.0
# MelbourneAirport          0.0       0.0
# Mildura                   0.0       0.0
# Moree                     0.2       0.0
# ...

# %%
tdf3 = df.copy()
tdf3=tdf3.groupby(tdf3.Location)[['Evaporation', 'Sunshine']].median()
tdf3
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                  4.2      8.40
# Albany                    3.8      6.90
# Albury                    NaN       NaN
# AliceSprings              8.2     10.60
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   3.1       NaN
# Brisbane                  5.2      9.40
# Cairns                    6.0      8.60
# Canberra                  3.6      8.00
# Cobar                     5.6      9.90
# CoffsHarbour              3.6      8.50
# Dartmoor                  2.8      6.50
# Darwin                    6.4     10.00
# GoldCoast                 NaN       NaN
# Hobart                    3.2      7.00
# Katherine                 7.2       NaN
# Launceston                5.2       NaN
# Melbourne                 4.0      6.50
# MelbourneAirport          4.0      6.50
# Mildura                   5.2      9.10
# Moree                     6.4     10.10
# ...

# %%
tdf4 = pd.merge(pd.merge(tdf1,tdf2,on='Location', suffixes=[None,'_min']),tdf3,on='Location',suffixes=['_max','_median'])
tdf4 = tdf4[['Evaporation_max', 'Evaporation_min', 'Sunshine_max', 'Sunshine_min', 'Evaporation_median', 'Sunshine_median']]
tdf4
# Out:
#                   Evaporation_max  Evaporation_min  Sunshine_max  \
# Location
# Adelaide                     43.4              0.0          13.9
# Albany                       33.6              0.0          13.8
# Albury                        NaN              NaN           NaN
# AliceSprings                 50.2              0.0          13.5
# BadgerysCreek                 NaN              NaN           NaN
# Ballarat                      NaN              NaN           NaN
# Bendigo                      15.4              0.0           NaN
# Brisbane                     44.0              0.0          13.5
# Cairns                       44.4              0.2          12.8
# Canberra                     20.0              0.0          13.6
# Cobar                        86.2              0.0          13.7
# CoffsHarbour                 19.8              0.0          13.8
# Dartmoor                     16.4              0.0          14.3
# ...

# %% [markdown]
# 19) Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
tdf
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01/12/2008   Albury     13.4     22.9       0.6           W
# 1       02/12/2008   Albury      7.4     25.1       0.0         WNW
# 2       03/12/2008   Albury     12.9     25.7       0.0         WSW
# 3       04/12/2008   Albury      9.2     28.0       0.0          NE
# 4       05/12/2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145454  20/06/2017    Uluru      3.5     21.8       0.0           E
# 145455  21/06/2017    Uluru      2.8     23.4       0.0           E
# 145456  22/06/2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23/06/2017    Uluru      5.4     26.9       0.0           N
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          SE
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
Perth=tdf[tdf.location == 'Perth'].sort_values(by='maxtemp', ascending=False)
Perth.date.iloc[0]
# Out:
# '05/01/2015'

# %% [markdown]
# 20) Group your dataframe by location and find out the averages of all numeric values.

# %%
tdf.groupby("location").mean()
# Out:
#                     mintemp    maxtemp  rainfall  windgustspeed  windspeed9am  \
# location
# Adelaide          12.571487  22.891254  1.576076      36.499211      9.954804
# Albury             9.518588  22.629555  1.904552      32.977394      8.209720
# AliceSprings      13.155254  29.281325  0.869484      40.531281     14.754603
# BadgerysCreek     11.135741  24.014949  2.215406      33.600409      8.053590
# Ballarat           7.348670  18.267930  1.706369      44.982719     19.976024
# Bendigo            8.611841  21.625609  1.631586      38.844948     12.945630
# Brisbane          16.414204  26.436043  3.119424      28.212881      6.950508
# Cairns            21.225099  29.559550  5.701852      38.026150     15.902649
# Canberra           6.670100  20.731579  1.745920      40.071682     10.444228
# Cobar             13.131412  25.853488  1.132655      36.750590     14.679717
# CoffsHarbour      14.522998  23.971493  4.990985      39.227925     15.273139
# ...
