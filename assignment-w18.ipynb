# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/weather-dataset-rattle-package/weatherAUS.csv

# %% [markdown]
# # 1- Read the dataset as a dataframe. Create a copy of your dataframe. Solve the rest of the questions using this dataframe copy.

# %%
d = pd.read_csv('/kaggle/input/weather-dataset-rattle-package/weatherAUS.csv')

# %%
df=d.copy()

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # 2- Find out the describe and info attributes of the dataframe. Analyze these information and create a short write-up according to your findings.

# %%
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %% [markdown]
# # My coment; mean ve 50% columns verileri birbirine yakin degerler iceriyor. Buradan verilerin normal dagilima yakin bir dagilim gosterdigi sonucuna varabiliriz.
# # Ayrica her row da, std column degerleri ile mean column degerlerini karsilastirabiliriz. Buradan std degeri buyuk olan verilerin dagiliminin ne kadar cok yayildigi sonucunu cikarabiliriz.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# # My coment; columns isimleri(23 adet) ve data types isimlerini (float64(16), object(7)) ogrenebiliriz. Ayrica her bir column nekadar non-null veri  iceriyor yada icermiyor anlayabiliriz.

# %% [markdown]
# # 3- Find out the shape and size info of the dataset.

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.size
# Out:
# 3345580

# %% [markdown]
# # 4- Find out the types values of the columns and save the result as a dataframe.

# %%
c = df.dtypes.to_frame('dtypes').reset_index()
c
# Out:
#             index   dtypes
# 0            Date   object
# 1        Location   object
# 2         MinTemp  float64
# 3         MaxTemp  float64
# 4        Rainfall  float64
# 5     Evaporation  float64
# 6        Sunshine  float64
# 7     WindGustDir   object
# 8   WindGustSpeed  float64
# 9      WindDir9am   object
# 10     WindDir3pm   object
# 11   WindSpeed9am  float64
# 12   WindSpeed3pm  float64
# 13    Humidity9am  float64
# 14    Humidity3pm  float64
# 15    Pressure9am  float64
# 16    Pressure3pm  float64
# 17       Cloud9am  float64
# 18       Cloud3pm  float64
# 19        Temp9am  float64
# 20        Temp3pm  float64
# 21      RainToday   object
# 22   RainTomorrow   object

# %%
c.columns = ['Columns','dtypes']

# %%
df_dtypes = pd.DataFrame(c,columns=['dtypes'])
df_dtypes
# Out:
#      dtypes
# 0    object
# 1    object
# 2   float64
# 3   float64
# 4   float64
# 5   float64
# 6   float64
# 7    object
# 8   float64
# 9    object
# 10   object
# 11  float64
# 12  float64
# 13  float64
# 14  float64
# 15  float64
# 16  float64
# 17  float64
# 18  float64
# 19  float64
# 20  float64
# 21   object
# 22   object

# %% [markdown]
# # 5- Find out the non-null counts of the columns and save the result as a dataframe.

# %%
notnull = df.count().to_frame('notnull').reset_index()
notnull
# Out:
#             index  notnull
# 0            Date   145460
# 1        Location   145460
# 2         MinTemp   143975
# 3         MaxTemp   144199
# 4        Rainfall   142199
# 5     Evaporation    82670
# 6        Sunshine    75625
# 7     WindGustDir   135134
# 8   WindGustSpeed   135197
# 9      WindDir9am   134894
# 10     WindDir3pm   141232
# 11   WindSpeed9am   143693
# 12   WindSpeed3pm   142398
# 13    Humidity9am   142806
# 14    Humidity3pm   140953
# 15    Pressure9am   130395
# 16    Pressure3pm   130432
# 17       Cloud9am    89572
# 18       Cloud3pm    86102
# 19        Temp9am   143693
# 20        Temp3pm   141851
# 21      RainToday   142199
# 22   RainTomorrow   142193

# %%
df_notnull = pd.DataFrame(notnull,columns=['notnull'])
df_notnull
# Out:
#     notnull
# 0    145460
# 1    145460
# 2    143975
# 3    144199
# 4    142199
# 5     82670
# 6     75625
# 7    135134
# 8    135197
# 9    134894
# 10   141232
# 11   143693
# 12   142398
# 13   142806
# 14   140953
# 15   130395
# 16   130432
# 17    89572
# 18    86102
# 19   143693
# 20   141851
# 21   142199
# 22   142193

# %% [markdown]
# # 6- Find out the null counts of the columns and save the result as a dataframe.

# %%
isnull = df.isna().sum().to_frame('isnull').reset_index()
isnull
# Out:
#             index  isnull
# 0            Date       0
# 1        Location       0
# 2         MinTemp    1485
# 3         MaxTemp    1261
# 4        Rainfall    3261
# 5     Evaporation   62790
# 6        Sunshine   69835
# 7     WindGustDir   10326
# 8   WindGustSpeed   10263
# 9      WindDir9am   10566
# 10     WindDir3pm    4228
# 11   WindSpeed9am    1767
# 12   WindSpeed3pm    3062
# 13    Humidity9am    2654
# 14    Humidity3pm    4507
# 15    Pressure9am   15065
# 16    Pressure3pm   15028
# 17       Cloud9am   55888
# 18       Cloud3pm   59358
# 19        Temp9am    1767
# 20        Temp3pm    3609
# 21      RainToday    3261
# 22   RainTomorrow    3267

# %%
df_isnull = pd.DataFrame(isnull,columns=['isnull'])
df_isnull
# Out:
#     isnull
# 0        0
# 1        0
# 2     1485
# 3     1261
# 4     3261
# 5    62790
# 6    69835
# 7    10326
# 8    10263
# 9    10566
# 10    4228
# 11    1767
# 12    3062
# 13    2654
# 14    4507
# 15   15065
# 16   15028
# 17   55888
# 18   59358
# 19    1767
# 20    3609
# 21    3261
# 22    3267

# %% [markdown]
# # 7- Find out the unique counts of the columns and save the result as a dataframe.

# %%
nunique = df.nunique().to_frame('nunique').reset_index()
nunique
# Out:
#             index  nunique
# 0            Date     3436
# 1        Location       49
# 2         MinTemp      389
# 3         MaxTemp      505
# 4        Rainfall      681
# 5     Evaporation      358
# 6        Sunshine      145
# 7     WindGustDir       16
# 8   WindGustSpeed       67
# 9      WindDir9am       16
# 10     WindDir3pm       16
# 11   WindSpeed9am       43
# 12   WindSpeed3pm       44
# 13    Humidity9am      101
# 14    Humidity3pm      101
# 15    Pressure9am      546
# 16    Pressure3pm      549
# 17       Cloud9am       10
# 18       Cloud3pm       10
# 19        Temp9am      441
# 20        Temp3pm      502
# 21      RainToday        2
# 22   RainTomorrow        2

# %%
df_nunique = pd.DataFrame(nunique,columns=['nunique'])
df_nunique
# Out:
#     nunique
# 0      3436
# 1        49
# 2       389
# 3       505
# 4       681
# 5       358
# 6       145
# 7        16
# 8        67
# 9        16
# 10       16
# 11       43
# 12       44
# 13      101
# 14      101
# 15      546
# 16      549
# 17       10
# 18       10
# 19      441
# 20      502
# 21        2
# 22        2

# %% [markdown]
# # 8- Merge the dataframes you created in questions 4-5-6-7.

# %%
df_merged = pd.concat([c,df_notnull,df_isnull,df_nunique],axis=1)
df_merged
# Out:
#           Columns   dtypes  notnull  isnull  nunique
# 0            Date   object   145460       0     3436
# 1        Location   object   145460       0       49
# 2         MinTemp  float64   143975    1485      389
# 3         MaxTemp  float64   144199    1261      505
# 4        Rainfall  float64   142199    3261      681
# 5     Evaporation  float64    82670   62790      358
# 6        Sunshine  float64    75625   69835      145
# 7     WindGustDir   object   135134   10326       16
# 8   WindGustSpeed  float64   135197   10263       67
# 9      WindDir9am   object   134894   10566       16
# 10     WindDir3pm   object   141232    4228       16
# 11   WindSpeed9am  float64   143693    1767       43
# 12   WindSpeed3pm  float64   142398    3062       44
# 13    Humidity9am  float64   142806    2654      101
# 14    Humidity3pm  float64   140953    4507      101
# 15    Pressure9am  float64   130395   15065      546
# 16    Pressure3pm  float64   130432   15028      549
# ...

# %% [markdown]
# # 9- Lowercase all column names.

# %%
df.columns = df.columns.str.lower()
df.sample(5)
# Out:
#               date          location  mintemp  maxtemp  rainfall  evaporation  \
# 132609  2016-04-30            Hobart     10.7     22.3       1.4          1.4
# 1537    2013-05-15            Albury      6.1     13.7       7.4          NaN
# 57234   2014-12-31          Ballarat      5.4     26.2       0.0          NaN
# 66835   2016-06-26  MelbourneAirport      2.2     10.2       0.0          0.4
# 88479   2012-07-02            Cairns     18.3     26.6       0.0          3.6
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# 132609       8.2           N           48.0        NNW  ...        72.0
# 1537         NaN         WNW           39.0         NE  ...        97.0
# 57234        NaN           W           39.0          S  ...        65.0
# 66835        5.3           N           41.0          N  ...        87.0
# 88479       10.6         SSE           43.0        SSE  ...        55.0
#
# ...

# %% [markdown]
# # 10- Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

# %%
df.raintoday.replace('No','NoRain',inplace = True)
df.raintoday.replace('Yes','Rain',inplace = True)
df.raintomorrow.replace('No','NoRain',inplace = True)
df.raintomorrow.replace('Yes','Rain',inplace = True)
df.sample(5)
# Out:
#              date       location  mintemp  maxtemp  rainfall  evaporation  \
# 74409  2015-12-03           Nhil      5.5     29.5       0.0          NaN
# 96313  2017-06-19     Townsville     15.1     26.4       0.0          NaN
# 82940  2014-07-25       Dartmoor      8.9     15.3       6.4          0.4
# 17171  2014-11-24      Newcastle     20.8     28.2      10.2          NaN
# 23350  2015-05-10  NorfolkIsland     14.3     21.1       1.8          4.2
#
#        sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# 74409       NaN         SSE           31.0        ESE  ...        54.0
# 96313       NaN          NE           35.0        SSE  ...        66.0
# 82940       4.5         WNW           30.0        NNW  ...       100.0
# 17171       NaN         NaN            NaN        NaN  ...        70.0
# 23350       2.2          SW           28.0        NaN  ...        61.0
#
#        humidity3pm  pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  \
# ...

# %% [markdown]
# # 11- Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.

# %%
df.date = pd.to_datetime(df.date)
df.date = df.date.dt.strftime('%d/%m/%Y')
df.head(3)
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity9am  humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8     NoRain
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3     NoRain
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2     NoRain
#
#    raintomorrow
# 0        NoRain
# 1        NoRain
# 2        NoRain
#
# ...

# %% [markdown]
# # 12- Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
df['difference'] = df['maxtemp'] - df['mintemp']
df.sample(3)
# Out:
#               date      location  mintemp  maxtemp  rainfall  evaporation  \
# 37364   16/05/2011    WaggaWagga     -2.6     11.2       0.0          1.0
# 138247  13/02/2015  AliceSprings     20.4     37.5       0.0         13.8
# 83214   25/04/2015      Dartmoor      3.5     15.1      13.0          1.0
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity3pm  \
# 37364        1.1         WSW           28.0         NE  ...        65.0
# 138247      12.6           E           52.0        ENE  ...        13.0
# 83214        3.2           S           39.0        NaN  ...         NaN
#
#         pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  \
# 37364        1033.1       1030.5       4.0       7.0      2.1     10.6
# 138247       1012.8       1009.0       1.0       3.0     31.4     36.9
# 83214        1010.1       1012.7       NaN       NaN      5.2     14.0
#
#         raintoday  raintomorrow  difference
# 37364      NoRain        NoRain        13.8
# ...

# %% [markdown]
# # 13- Remove the evaporation and sunshine columns from the dataset permanently.

# %%
df.drop('evaporation',axis = 1, inplace = True)
df.drop('sunshine',axis = 1, inplace = True)
df.sample(3)
# Out:
#              date       location  mintemp  maxtemp  rainfall windgustdir  \
# 85852  17/10/2013       Brisbane     15.8     27.8       0.0          NE
# 21232  24/04/2009  NorfolkIsland     19.7     23.4       1.2         WNW
# 40500  20/09/2011    Williamtown     14.5     30.5       0.0          NW
#
#        windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 85852           33.0          N        NNE           9.0  ...         57.0
# 21232           35.0        WNW        WNW          19.0  ...         60.0
# 40500           76.0        NNE        WNW          13.0  ...         27.0
#
#        pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  \
# 85852       1020.3       1015.4       1.0       2.0     25.3     25.4
# 21232       1011.6       1011.1       2.0       3.0     22.1     22.7
# 40500       1008.0       1004.4       4.0       1.0     23.2     28.1
#
#        raintoday  raintomorrow difference
# 85852     NoRain        NoRain       12.0
# ...

# %% [markdown]
# # 14- Find out the most rainy day for each city.

# %%
df_rainyday = df.groupby(df.location)['rainfall'].idxmax().to_frame('rainyday')
day = df_rainyday.rainyday.to_list()
df.date[day].reset_index()
# Out:
#      index        date
# 0    98285  14/02/2014
# 1     1156  01/03/2012
# 2   136525  28/02/2010
# 3     4468  29/01/2013
# 4    55898  05/02/2011
# 5    58938  05/02/2011
# 6    86414  02/05/2015
# 7    87242  12/01/2009
# 8    46715  03/12/2010
# 9     7832  16/02/2014
# 10   11681  05/06/2016
# 11   81741  14/01/2011
# 12  140071  16/02/2011
# 13   91455  29/04/2012
# 14  132137  14/01/2015
# 15  143335  27/12/2015
# 16  135557  29/01/2016
# 17   68151  07/02/2011
# 18   65714  01/06/2013
# 19   71158  05/02/2011
# 20   13096  26/11/2011
# 21  100287  14/01/2011
# 22   53221  04/03/2012
# 23   73505  12/06/2013
# 24   19661  24/06/2013
# 25   23667  22/03/2016
# 26  103259  08/12/2010
# 27  115660  07/12/2011
# 28   25263  10/02/2012
# 29  123695  10/02/2017
# 30  118185  11/07/2010
# 31   75723  14/01/2011
# 32   29379  21/04/2015
# 33   63259  07/12/2014
# 34  125255  02/03/2013
# 35   32723  21/04/2015
# 36   35544  15/10/2014
# 37   93344  03/02/2009
# 38   49761  09/12/2010
# ...

# %% [markdown]
# # 15- Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
df_Albury = df[df.location == 'Albury']
df_Albury
# Out:
#             date location  mintemp  maxtemp  rainfall windgustdir  \
# 0     01/12/2008   Albury     13.4     22.9       0.6           W
# 1     02/12/2008   Albury      7.4     25.1       0.0         WNW
# 2     03/12/2008   Albury     12.9     25.7       0.0         WSW
# 3     04/12/2008   Albury      9.2     28.0       0.0          NE
# 4     05/12/2008   Albury     17.5     32.3       1.0           W
# ...          ...      ...      ...      ...       ...         ...
# 3035  21/06/2017   Albury      1.2     15.2       0.4         ENE
# 3036  22/06/2017   Albury      0.8     13.4       0.0           W
# 3037  23/06/2017   Albury      1.1     11.9       0.0          SE
# 3038  24/06/2017   Albury      1.1     14.1       0.2         WSW
# 3039  25/06/2017   Albury      3.9     10.9       0.0         NNW
#
#       windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 0              44.0          W        WNW          20.0  ...         22.0
# ...

# %%
df_Albury.sort_values(by = 'maxtemp')
# Out:
#             date location  mintemp  maxtemp  rainfall windgustdir  \
# 2328  15/07/2015   Albury      4.4      6.8      10.0          NE
# 2675  26/06/2016   Albury     -1.3      7.5       0.0         ENE
# 193   12/06/2009   Albury     -1.3      8.2       0.0         ESE
# 2673  24/06/2016   Albury      6.6      8.2       4.0           W
# 919   08/07/2011   Albury     -0.5      8.3       0.0         WNW
# ...          ...      ...      ...      ...       ...         ...
# 984   11/09/2011   Albury      NaN      NaN       NaN         NaN
# 985   12/09/2011   Albury      NaN      NaN       NaN         NaN
# 1529  07/05/2013   Albury      3.9      NaN       0.0         NaN
# 2031  21/09/2014   Albury      3.4      NaN       0.0         NaN
# 2032  22/09/2014   Albury      NaN      NaN       NaN         NaN
#
#       windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 2328           30.0          S        SSE          13.0  ...         93.0
# ...

# %% [markdown]
# # 16- Find out the NaN counts for each column.

# %%
isNaN = df.isna().sum().to_frame('isNaN').reset_index()
isNaN
# Out:
#             index  isNaN
# 0            date      0
# 1        location      0
# 2         mintemp   1485
# 3         maxtemp   1261
# 4        rainfall   3261
# 5     windgustdir  10326
# 6   windgustspeed  10263
# 7      winddir9am  10566
# 8      winddir3pm   4228
# 9    windspeed9am   1767
# 10   windspeed3pm   3062
# 11    humidity9am   2654
# 12    humidity3pm   4507
# 13    pressure9am  15065
# 14    pressure3pm  15028
# 15       cloud9am  55888
# 16       cloud3pm  59358
# 17        temp9am   1767
# 18        temp3pm   3609
# 19      raintoday   3261
# 20   raintomorrow   3267
# 21     difference   1881

# %% [markdown]
# # 17- Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
df.dropna(subset=['windgustdir'],inplace=True)
df.tail()
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 145454  20/06/2017    Uluru      3.5     21.8       0.0           E
# 145455  21/06/2017    Uluru      2.8     23.4       0.0           E
# 145456  22/06/2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23/06/2017    Uluru      5.4     26.9       0.0           N
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          SE
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 145454           31.0        ESE          E          15.0  ...         27.0
# 145455           31.0         SE        ENE          13.0  ...         24.0
# 145456           22.0         SE          N          13.0  ...         21.0
# 145457           37.0         SE        WNW           9.0  ...         24.0
# 145458           28.0        SSE          N          13.0  ...         24.0
#
#         pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  \
# ...

# %%
df.shape
# Out:
# (135134, 22)

# %% [markdown]
# # 18- Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
new_df = d.copy()
min_value = new_df.groupby('Location')[['Evaporation','Sunshine']].min()
min_value
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                  0.0       0.0
# Albany                    0.0       0.0
# Albury                    NaN       NaN
# AliceSprings              0.0       0.0
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   0.0       NaN
# Brisbane                  0.0       0.0
# Cairns                    0.2       0.0
# Canberra                  0.0       0.0
# Cobar                     0.0       0.0
# CoffsHarbour              0.0       0.0
# Dartmoor                  0.0       0.0
# Darwin                    0.2       0.0
# GoldCoast                 NaN       NaN
# Hobart                    0.0       0.0
# Katherine                 0.0       NaN
# Launceston                0.0       NaN
# Melbourne                 0.0       0.0
# MelbourneAirport          0.0       0.0
# Mildura                   0.0       0.0
# Moree                     0.2       0.0
# ...

# %%
max_value = new_df.groupby('Location')[['Evaporation','Sunshine']].max()
max_value
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                 43.4      13.9
# Albany                   33.6      13.8
# Albury                    NaN       NaN
# AliceSprings             50.2      13.5
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                  15.4       NaN
# Brisbane                 44.0      13.5
# Cairns                   44.4      12.8
# Canberra                 20.0      13.6
# Cobar                    86.2      13.7
# CoffsHarbour             19.8      13.8
# Dartmoor                 16.4      14.3
# Darwin                   19.2      12.3
# GoldCoast                 NaN       NaN
# Hobart                   20.2      14.2
# Katherine                31.0       NaN
# Launceston               30.4       NaN
# Melbourne                23.8      13.9
# MelbourneAirport         23.8      13.9
# Mildura                  23.2      14.5
# Moree                    65.4      14.0
# ...

# %%
median_value = new_df.groupby('Location')[['Evaporation','Sunshine']].median()
median_value
# Out:
#                   Evaporation  Sunshine
# Location
# Adelaide                  4.2      8.40
# Albany                    3.8      6.90
# Albury                    NaN       NaN
# AliceSprings              8.2     10.60
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   3.1       NaN
# Brisbane                  5.2      9.40
# Cairns                    6.0      8.60
# Canberra                  3.6      8.00
# Cobar                     5.6      9.90
# CoffsHarbour              3.6      8.50
# Dartmoor                  2.8      6.50
# Darwin                    6.4     10.00
# GoldCoast                 NaN       NaN
# Hobart                    3.2      7.00
# Katherine                 7.2       NaN
# Launceston                5.2       NaN
# Melbourne                 4.0      6.50
# MelbourneAirport          4.0      6.50
# Mildura                   5.2      9.10
# Moree                     6.4     10.10
# ...

# %%
df_min_max_median = pd.concat([min_value,max_value,median_value], axis = 1)
df_min_max_median
# Out:
#                   Evaporation  Sunshine  Evaporation  Sunshine  Evaporation  \
# Location
# Adelaide                  0.0       0.0         43.4      13.9          4.2
# Albany                    0.0       0.0         33.6      13.8          3.8
# Albury                    NaN       NaN          NaN       NaN          NaN
# AliceSprings              0.0       0.0         50.2      13.5          8.2
# BadgerysCreek             NaN       NaN          NaN       NaN          NaN
# Ballarat                  NaN       NaN          NaN       NaN          NaN
# Bendigo                   0.0       NaN         15.4       NaN          3.1
# Brisbane                  0.0       0.0         44.0      13.5          5.2
# Cairns                    0.2       0.0         44.4      12.8          6.0
# Canberra                  0.0       0.0         20.0      13.6          3.6
# Cobar                     0.0       0.0         86.2      13.7          5.6
# ...

# %% [markdown]
# # 19- Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
df_perth = df[df.location == 'Perth']
df_perth.head()
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 120638  01/07/2008    Perth      2.7     18.8       0.0         ENE
# 120639  02/07/2008    Perth      6.4     20.7       0.0          NE
# 120640  03/07/2008    Perth      6.5     19.9       0.4          NE
# 120641  04/07/2008    Perth      9.5     19.2       1.8           W
# 120642  05/07/2008    Perth      9.5     16.4       1.8         WSW
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 120638           20.0        NaN          E           0.0  ...         53.0
# 120639           22.0        ESE        ENE           6.0  ...         39.0
# 120640           31.0        NaN        WNW           0.0  ...         71.0
# 120641           26.0        NNE        NNW          11.0  ...         73.0
# 120642           44.0          W         SW          13.0  ...         57.0
#
#         pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  \
# ...

# %%
df_hottest = df_perth.groupby(df_perth.location)['maxtemp'].idxmax().to_frame('hottest')
days = df_hottest.hottest.to_list()
df_perth.date[days]
# Out:
# 122928    05/01/2015
# Name: date, dtype: object

# %% [markdown]
# # 20- Group your dataframe by location and find out the averages of all numeric values.

# %%
df.groupby('location').mean()
# Out:
#                     mintemp    maxtemp  rainfall  windgustspeed  windspeed9am  \
# location
# Adelaide          12.571487  22.891254  1.576076      36.499211      9.954804
# Albury             9.518588  22.629555  1.904552      32.977394      8.209720
# AliceSprings      13.155254  29.281325  0.869484      40.531281     14.754603
# BadgerysCreek     11.135741  24.014949  2.215406      33.600409      8.053590
# Ballarat           7.348670  18.267930  1.706369      44.982719     19.976024
# Bendigo            8.611841  21.625609  1.631586      38.844948     12.945630
# Brisbane          16.414204  26.436043  3.119424      28.212881      6.950508
# Cairns            21.225099  29.559550  5.701852      38.026150     15.902649
# Canberra           6.670100  20.731579  1.745920      40.071682     10.444228
# Cobar             13.131412  25.853488  1.132655      36.750590     14.679717
# CoffsHarbour      14.522998  23.971493  4.990985      39.227925     15.273139
# ...
