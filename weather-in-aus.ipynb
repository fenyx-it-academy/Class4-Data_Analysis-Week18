# %%
# https://www.kaggle.com/cabirerguven/weather-in-aus

# %%
#https://www.kaggle.com/cabirerguven/weather-in-aus
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/weather-dataset-rattle-package/weatherAUS.csv

# %%
# 1) Read the dataset as a dataframe. Create a copy of your dataframe
df = pd.read_csv("../input/weather-dataset-rattle-package/weatherAUS.csv")
df_weather = df.copy()

# %%
# 2.Find out the describe and info attributes of the dataframe. 
# Analyze these information and create a short write-up according to your findings.
df_weather.describe()


# Here we can see statistical values of given csv file such as min and max temperature, wind, sunshine, humidity pressure cloud 
# and many other information. Count, mean, std, quartiles etc tell us a lot about whole data.
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df_weather.info()
# here, we can see total entry numbers, all the column names, , their data types and non-null counts for given csv file.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# 3.1 Find out the shape and 
df_weather.shape
# There are total 14560 entry and 23 columns
# Out:
# (145460, 23)

# %%
# 3.2 size info of the dataset.
df_weather.size
# There are total 3345580 elements in this object.
# Out:
# 3345580

# %%
# 4.Find out the types values of the columns and save the result as a dataframe.
DATA_TYPES = pd.DataFrame(df.dtypes,columns=['DATA_TYPES'])
DATA_TYPES
# Out:
#               DATA_TYPES
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object

# %%
# 5.Find out the non-null counts of the columns and save the result as a dataframe.
NOT_NULL = pd.DataFrame(df.notnull().sum().to_frame('NOT_NULL'))
NOT_NULL
# Out:
#                NOT_NULL
# Date             145460
# Location         145460
# MinTemp          143975
# MaxTemp          144199
# Rainfall         142199
# Evaporation       82670
# Sunshine          75625
# WindGustDir      135134
# WindGustSpeed    135197
# WindDir9am       134894
# WindDir3pm       141232
# WindSpeed9am     143693
# WindSpeed3pm     142398
# Humidity9am      142806
# Humidity3pm      140953
# Pressure9am      130395
# Pressure3pm      130432
# Cloud9am          89572
# Cloud3pm          86102
# Temp9am          143693
# Temp3pm          141851
# RainToday        142199
# RainTomorrow     142193

# %%
# 6.Find out the null counts of the columns and save the result as a dataframe.
ISNULL = pd.DataFrame(df.isnull().sum(), columns=['ISNULL'])
ISNULL
# Out:
#                ISNULL
# Date                0
# Location            0
# MinTemp          1485
# MaxTemp          1261
# Rainfall         3261
# Evaporation     62790
# Sunshine        69835
# WindGustDir     10326
# WindGustSpeed   10263
# WindDir9am      10566
# WindDir3pm       4228
# WindSpeed9am     1767
# WindSpeed3pm     3062
# Humidity9am      2654
# Humidity3pm      4507
# Pressure9am     15065
# Pressure3pm     15028
# Cloud9am        55888
# Cloud3pm        59358
# Temp9am          1767
# Temp3pm          3609
# RainToday        3261
# RainTomorrow     3267

# %%
# 7.Find out the unique counts of the columns and save the result as a dataframe.
UNIQUE = pd.DataFrame(df.nunique(), columns=['UNIQUE'])
UNIQUE
# Out:
#                UNIQUE
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          681
# Evaporation       358
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           441
# Temp3pm           502
# RainToday           2
# RainTomorrow        2

# %%
# 8. Merge the dataframes you created in questions 4-5-6-7.
merged = pd.concat([DATA_TYPES, NOT_NULL, ISNULL, UNIQUE], axis=1).reset_index()
merged
# Out:
#             index DATA_TYPES  NOT_NULL  ISNULL  UNIQUE
# 0            Date     object    145460       0    3436
# 1        Location     object    145460       0      49
# 2         MinTemp    float64    143975    1485     389
# 3         MaxTemp    float64    144199    1261     505
# 4        Rainfall    float64    142199    3261     681
# 5     Evaporation    float64     82670   62790     358
# 6        Sunshine    float64     75625   69835     145
# 7     WindGustDir     object    135134   10326      16
# 8   WindGustSpeed    float64    135197   10263      67
# 9      WindDir9am     object    134894   10566      16
# 10     WindDir3pm     object    141232    4228      16
# 11   WindSpeed9am    float64    143693    1767      43
# 12   WindSpeed3pm    float64    142398    3062      44
# 13    Humidity9am    float64    142806    2654     101
# 14    Humidity3pm    float64    140953    4507     101
# 15    Pressure9am    float64    130395   15065     546
# ...

# %%
# 9.Lowercase all column names.

df_weather.columns = df_weather.columns.str.lower()
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
# 10.Change all the No values to NoRain and all the Yes values to Rain in raintoday and 
# raintomorrow columns.

df_weather.raintoday.replace('No', 'noRain', inplace=True)
df_weather.raintomorrow.replace('No', 'noRain', inplace=True)
df_weather.raintoday.replace('Yes', 'Rain', inplace=True)
df_weather.raintomorrow.replace('Yes', 'Rain', inplace=True)

df_weather['raintoday'].sample(20)
# Out:
# 99030     noRain
# 24030     noRain
# 9035      noRain
# 66715     noRain
# 58164     noRain
# 65929       Rain
# 117623    noRain
# 142332      Rain
# 121991    noRain
# 88727       Rain
# 10199     noRain
# 127767      Rain
# 123273    noRain
# 2750        Rain
# 25198     noRain
# 62092     noRain
# 81570     noRain
# 40293     noRain
# 112142      Rain
# 24314     noRain
# Name: raintoday, dtype: object

# %%
# 11. Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY
df_weather.date=pd.to_datetime(df_weather.date,format='%Y/%m/%d')
df_weather['date']
# Out:
# 0        2008-12-01
# 1        2008-12-02
# 2        2008-12-03
# 3        2008-12-04
# 4        2008-12-05
#             ...
# 145455   2017-06-21
# 145456   2017-06-22
# 145457   2017-06-23
# 145458   2017-06-24
# 145459   2017-06-25
# Name: date, Length: 145460, dtype: datetime64[ns]

# %%
# 12. Remove Create a new column called "difference", calculate the difference 
# between maxtemp and mintemp columns for each row, and store the value in this new column.

df_weather['difference'] = df_weather['maxtemp'] - df_weather['mintemp'] 
df_weather['difference']
# Out:
# 0          9.5
# 1         17.7
# 2         12.8
# 3         18.8
# 4         14.8
#           ...
# 145455    20.6
# 145456    21.7
# 145457    21.5
# 145458    19.2
# 145459     NaN
# Name: difference, Length: 145460, dtype: float64

# %%
# 13. Remove the evaporation and sunshine columns from the dataset permanently.
df_weather#.#drop#(['evaporation', 'sunshine'], axis=1, inplace=True)
# Out:
#              date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 145455 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459 2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
# 14. Find out the most rainy day for each city.

# %%
# 15. Filter out all the data for the city 'Albury' and then sort according to maxtemp column.
df2 =df_weather[df_weather.location == 'Albury']  
df2.sort_values(by=['maxtemp'])
# Out:
#            date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 2328 2015-07-15   Albury      4.4      6.8      10.0          NaN       NaN
# 2675 2016-06-26   Albury     -1.3      7.5       0.0          NaN       NaN
# 193  2009-06-12   Albury     -1.3      8.2       0.0          NaN       NaN
# 2673 2016-06-24   Albury      6.6      8.2       4.0          NaN       NaN
# 919  2011-07-08   Albury     -0.5      8.3       0.0          NaN       NaN
# ...         ...      ...      ...      ...       ...          ...       ...
# 984  2011-09-11   Albury      NaN      NaN       NaN          NaN       NaN
# 985  2011-09-12   Albury      NaN      NaN       NaN          NaN       NaN
# 1529 2013-05-07   Albury      3.9      NaN       0.0          NaN       NaN
# 2031 2014-09-21   Albury      3.4      NaN       0.0          NaN       NaN
# 2032 2014-09-22   Albury      NaN      NaN       NaN          NaN       NaN
#
# ...

# %%
# 16. Find out the NaN counts for each column.

df_weather.isnull().sum()
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# evaporation      62790
# sunshine         69835
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %%
# 19. Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')
df_weather.groupby('location')['maxtemp'].max()
# Out:
# location
# Adelaide            45.7
# Albany              39.0
# Albury              44.8
# AliceSprings        44.9
# BadgerysCreek       46.4
# Ballarat            44.1
# Bendigo             45.4
# Brisbane            38.9
# Cairns              38.6
# Canberra            42.0
# Cobar               46.6
# CoffsHarbour        39.2
# Dartmoor            44.4
# Darwin              38.0
# GoldCoast           37.9
# Hobart              41.8
# Katherine           42.0
# Launceston          39.0
# Melbourne           46.4
# MelbourneAirport    46.8
# Mildura             46.7
# Moree               47.3
# MountGambier        44.9
# MountGinini         31.1
# Newcastle           44.1
# Nhil                45.3
# NorahHead           44.0
# NorfolkIsland       28.4
# Nuriootpa           44.1
# PearceRAAF          45.4
# Penrith             46.9
# Perth               44.4
# PerthAirport        44.2
# Portland            42.5
# Richmond            47.0
# Sale                44.4
# ...

# %%
# 17. Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

df_weather.dropna(subset=['windgustdir'], axis=0, inplace=True)

# %%
# 18. Create a new dataframe, use "Location" column as the index of the dataframe, display 
# the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.
min = df_weather.groupby('location')[['evaporation', 'sunshine']].min()
max = df_weather.groupby('location')[['evaporation', 'sunshine']].max()
median = df_weather.groupby('location')[['evaporation', 'sunshine']].median()


df_merged = pd.concat([min,min,median], axis = 1)
df_merged
# Out:
#                   evaporation  sunshine  evaporation  sunshine  evaporation  \
# location
# Adelaide                  0.0       0.0          0.0       0.0          4.2
# Albury                    NaN       NaN          NaN       NaN          NaN
# AliceSprings              0.0       0.0          0.0       0.0          8.2
# BadgerysCreek             NaN       NaN          NaN       NaN          NaN
# Ballarat                  NaN       NaN          NaN       NaN          NaN
# Bendigo                   0.0       NaN          0.0       NaN          3.1
# Brisbane                  0.0       0.0          0.0       0.0          5.2
# Cairns                    0.2       0.0          0.2       0.0          6.0
# Canberra                  0.0       0.0          0.0       0.0          3.4
# Cobar                     0.0       0.0          0.0       0.0          5.6
# CoffsHarbour              0.0       0.0          0.0       0.0          3.6
# ...

# %%
# 19. Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

df_weather[df_weather.location=='Perth'][['location','date','maxtemp']].sort_values(by=['maxtemp'], ascending=False).iloc[0]
# Out:
# location                  Perth
# date        2009-06-23 00:00:00
# maxtemp                    12.8
# Name: 120995, dtype: object

# %%
# 20.Group your dataframe by location and find out the averages of all numeric values.
df_weather.groupby('location').mean()
# Out:
#                     mintemp    maxtemp  rainfall  evaporation  sunshine  \
# location
# Adelaide          12.571487  22.891254  1.576076     5.757117  7.742417
# Albury             9.518588  22.629555  1.904552          NaN       NaN
# AliceSprings      13.155254  29.281325  0.869484     9.042405  9.592820
# BadgerysCreek     11.135741  24.014949  2.215406          NaN       NaN
# Ballarat           7.348670  18.267930  1.706369          NaN       NaN
# Bendigo            8.611841  21.625609  1.631586     3.835616       NaN
# Brisbane          16.414204  26.436043  3.119424     5.406064  8.069265
# Cairns            21.225099  29.559550  5.701852     6.244197  7.577948
# Canberra           6.670100  20.731579  1.745920     4.134289  7.419064
# Cobar             13.131412  25.853488  1.132655     6.751995  8.693236
# CoffsHarbour      14.522998  23.971493  4.990985     3.912857  7.353320
# Dartmoor           8.620518  19.696769  2.150272     3.354226  6.419215
# ...
